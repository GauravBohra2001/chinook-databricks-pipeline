# %%
server = "chinook-gaurav-srv.database.windows.net"
database = "ChinookDB"
username = "gauravbohra7370"
password = "soptot-pahMi7-sikdid"

jdbc_url = f"jdbc:sqlserver://{server}:1433;database={database};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30"

connection_properties = {
    "user": username,
    "password": password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

df = spark.read.jdbc(
    url=jdbc_url,
    table="chinook.Album",
    properties=connection_properties
)

df.display()
